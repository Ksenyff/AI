# %% [markdown]
# <a href="https://colab.research.google.com/github/Ksenyff/AI/blob/main/HW3.Spiridonova.Ksenia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Домашнее задание №3 - Корреляционный анализ
#
# Каждый студент получает [свой датасет](https://drive.google.com/drive/folders/1gMYrRxxDely91dzyv9d5pHPWHK0NoFVQ?usp=sharing) из [списка](https://docs.google.com/spreadsheets/d/1iGoCdAYM-_no5xBg3dZbEyB_1ykbT2YrhAGfjAlKeDM/edit?usp=sharing) для выполнения корреляционного анализа. Необходимо выполнить поставленные задачи.

# %% [markdown]
# Выполненную работу нужно отправить файлом IPYNB на почту **aneremin@it.kfu.ru** до **29.10.25 17:20**
#
# Название файла и темы письма необходимо оформить в формате **HW3.M2.2025.Имя.Фамилия**

# %% [markdown]
# ## Задачи:
# 1. Рассчитать средние значения отклика для каждого эксперимента
# 2. Построить графики для каждой каждой пары фактора и среднего значения отклика
# 3. Рассчитать ковариацию для каждой каждой пары фактора и среднего значения отклика
# 4. Выполнить корреляционный анализ
# - построить тепловые карты корреляций Пирсона, Спирмена и Кендалла и проверить значимость коэффициентов
# - сделать вывод о влиянии факторов между собой и на отклик

# %% [markdown]
# Загрузка датасета

# %%
import numpy as np

path_to_dataset = 'УКАЖИТЕ ПУТЬ ДО ВАШЕГО ДАТАСЕТА'
data = np.load(path_to_dataset, allow_pickle=True)
n, m, X, Y = data

print("Количество экспериментов n =", n)
print("Количество повторений в каждом эксперименте m =", m)
print("Количество факторов r =", X.shape[1])
